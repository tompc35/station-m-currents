# %%
import otis_tide_pred as otp
import numpy as np
import matplotlib.pyplot as plt

# %%
modfile = '/Users/tomconnolly/work/Data/OSU_TPXO/tpxo9/Model_tpxo9'
#modfile = '/Users/tomconnolly/work/Tools/OtisTidalPrediction/DATA/Model_haw'

# %%
# dates = np.arange(np.datetime64('2018-04-03 00:00'),
#                   np.datetime64('2018-05-03 00:00'), dtype='datetime64[h]' )

# %%
lon = np.array([-123])
lat = np.array([34+50/60])

# test numpy datetime64 dates
dates = np.arange(np.datetime64('2005-04-03 00:00'),
                  np.datetime64('2005-05-03 00:00'), dtype='datetime64[h]' )

#lon = np.array([198, 199, ])
#lat = np.array([21, 19])

# %%
h, u, v = otp.tide_pred(modfile, lon, lat, dates,conlist=None);
# Out:
# ['2005-04-03T00' '2005-04-03T01' '2005-04-03T02' '2005-04-03T03'
#  '2005-04-03T04' '2005-04-03T05' '2005-04-03T06' '2005-04-03T07'
#  '2005-04-03T08' '2005-04-03T09' '2005-04-03T10' '2005-04-03T11'
#  '2005-04-03T12' '2005-04-03T13' '2005-04-03T14' '2005-04-03T15'
#  '2005-04-03T16' '2005-04-03T17' '2005-04-03T18' '2005-04-03T19'
#  '2005-04-03T20' '2005-04-03T21' '2005-04-03T22' '2005-04-03T23'
#  '2005-04-04T00' '2005-04-04T01' '2005-04-04T02' '2005-04-04T03'
#  '2005-04-04T04' '2005-04-04T05' '2005-04-04T06' '2005-04-04T07'
#  '2005-04-04T08' '2005-04-04T09' '2005-04-04T10' '2005-04-04T11'
#  '2005-04-04T12' '2005-04-04T13' '2005-04-04T14' '2005-04-04T15'
#  '2005-04-04T16' '2005-04-04T17' '2005-04-04T18' '2005-04-04T19'
#  '2005-04-04T20' '2005-04-04T21' '2005-04-04T22' '2005-04-04T23'
#  '2005-04-05T00' '2005-04-05T01' '2005-04-05T02' '2005-04-05T03'
#  '2005-04-05T04' '2005-04-05T05' '2005-04-05T06' '2005-04-05T07'
# ...

# %%
plt.plot(dates,u[:,0]*4000,dates,v[:,0]*4000)

# %%
plt.plot(dates,h)
