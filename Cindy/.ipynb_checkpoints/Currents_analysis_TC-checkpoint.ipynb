# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
current_file = '../data/Rover_II_Current_Mag_Hourly_Avg_pad_2018.csv'

# %%
df = pd.read_csv(current_file,parse_dates=[1])

# %%
df.head()
# Out:
#    Unnamed: 0 Date_time_Merge_hour  Current_mag  Easting (cm/sec)  \
# 0           1  2011-11-20 13:00:00     7.712734         -3.678000
# 1           2  2011-11-20 14:00:00     1.711170          1.253333
# 2           3  2011-11-20 15:00:00     2.024802          1.080000
# 3           4  2011-11-20 16:00:00     3.567306         -1.413333
# 4           5  2011-11-20 17:00:00          NaN               NaN
#
#    Northing (cm/sec)  Minutes  Seconds       Date_time_R
# 0          -1.354000     10.8     32.0  11/20/2011 13:11
# 1          -0.853333     16.0     13.0  11/20/2011 13:56
# 2          -1.430000     25.0     30.0  11/20/2011 14:55
# 3          -3.036667     19.0     28.0  11/20/2011 15:59
# 4                NaN      NaN      NaN               NaN

# %%
df['Date_time_R'] = pd.to_datetime(df['Date_time_R'])

# %%
df = df.set_index('Date_time_R')

# %%
new_df = df.drop('Unnamed: 0', axis = 1)

# %%
#calculating speed for the whole data set

new_df['speed'] = np.sqrt((new_df['Easting (cm/sec)']**2) + (new_df['Northing (cm/sec)']**2))

new_df.head()
# Out:
#                     Date_time_Merge_hour  Current_mag  Easting (cm/sec)  \
# Date_time_R
# 2011-11-20 13:11:00  2011-11-20 13:00:00     7.712734         -3.678000
# 2011-11-20 13:56:00  2011-11-20 14:00:00     1.711170          1.253333
# 2011-11-20 14:55:00  2011-11-20 15:00:00     2.024802          1.080000
# 2011-11-20 15:59:00  2011-11-20 16:00:00     3.567306         -1.413333
# NaT                  2011-11-20 17:00:00          NaN               NaN
#
#                      Northing (cm/sec)  Minutes  Seconds     speed
# Date_time_R
# 2011-11-20 13:11:00          -1.354000     10.8     32.0  3.919311
# 2011-11-20 13:56:00          -0.853333     16.0     13.0  1.516253
# 2011-11-20 14:55:00          -1.430000     25.0     30.0  1.792010
# 2011-11-20 15:59:00          -3.036667     19.0     28.0  3.349456
# NaT                                NaN      NaN      NaN       NaN

# %%
monthly_averages_total = new_df.resample('1m').mean()

# %%
plt.figure(figsize = (10,5))
plt.plot(monthly_averages_total.index, monthly_averages_total['speed'])
plt.xlabel('Time [year]')
plt.ylabel('Speed [cm/s]')
# Out:
# Text(0, 0.5, 'Speed [cm/s]')

# %%
#separating out the data from the year 2016-2018
dates_2016_2018 = df.loc['2016-01-01':'2018-12-31']
dates_2016_2018['dates'] = dates_2016_2018.index

dates_2016_2018.head()
# Out:
# /Users/tomconnolly/programs/anaconda/envs/py37/lib/python3.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#                      Unnamed: 0 Date_time_Merge_hour  Current_mag  \
# Date_time_R
# 2016-01-01 00:56:00       36061  2016-01-01 01:00:00     0.638790
# 2016-01-01 01:59:00       36062  2016-01-01 02:00:00     0.793868
# 2016-01-01 03:02:00       36063  2016-01-01 03:00:00     0.357678
# 2016-01-01 04:07:00       36064  2016-01-01 04:00:00     0.810862
# 2016-01-01 04:53:00       36065  2016-01-01 05:00:00     0.987912
#
#                      Easting (cm/sec)  Northing (cm/sec)    Minutes  \
# Date_time_R
# 2016-01-01 00:56:00             0.170           0.433333  36.000000
# 2016-01-01 01:59:00             0.560           0.560000  29.000000
# 2016-01-01 03:02:00             0.170           0.130000  22.333333
# 2016-01-01 04:07:00             0.055          -0.770000  37.500000
# 2016-01-01 04:53:00             0.300          -0.930000  23.000000
#
#                        Seconds               dates
# Date_time_R
# 2016-01-01 00:56:00  39.333333 2016-01-01 00:56:00
# 2016-01-01 01:59:00  38.500000 2016-01-01 01:59:00
# 2016-01-01 03:02:00  18.000000 2016-01-01 03:02:00
# 2016-01-01 04:07:00  29.000000 2016-01-01 04:07:00
# 2016-01-01 04:53:00  40.000000 2016-01-01 04:53:00

# %%
#calculating the speed of the current 
dates_2016_2018['speed'] = np.sqrt((dates_2016_2018['Easting (cm/sec)']**2) + (dates_2016_2018['Northing (cm/sec)']**2))
dates_2016_2018.head()
# Out:
# /Users/tomconnolly/programs/anaconda/envs/py37/lib/python3.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                      Unnamed: 0 Date_time_Merge_hour  Current_mag  \
# Date_time_R
# 2016-01-01 00:56:00       36061  2016-01-01 01:00:00     0.638790
# 2016-01-01 01:59:00       36062  2016-01-01 02:00:00     0.793868
# 2016-01-01 03:02:00       36063  2016-01-01 03:00:00     0.357678
# 2016-01-01 04:07:00       36064  2016-01-01 04:00:00     0.810862
# 2016-01-01 04:53:00       36065  2016-01-01 05:00:00     0.987912
#
#                      Easting (cm/sec)  Northing (cm/sec)    Minutes  \
# Date_time_R
# 2016-01-01 00:56:00             0.170           0.433333  36.000000
# 2016-01-01 01:59:00             0.560           0.560000  29.000000
# 2016-01-01 03:02:00             0.170           0.130000  22.333333
# 2016-01-01 04:07:00             0.055          -0.770000  37.500000
# 2016-01-01 04:53:00             0.300          -0.930000  23.000000
#
#                        Seconds               dates     speed
# Date_time_R
# 2016-01-01 00:56:00  39.333333 2016-01-01 00:56:00  0.465487
# 2016-01-01 01:59:00  38.500000 2016-01-01 01:59:00  0.791960
# 2016-01-01 03:02:00  18.000000 2016-01-01 03:02:00  0.214009
# 2016-01-01 04:07:00  29.000000 2016-01-01 04:07:00  0.771962
# 2016-01-01 04:53:00  40.000000 2016-01-01 04:53:00  0.977190

# %%
plt.figure(figsize = (25,10))
plt.plot(dates_2016_2018.index,dates_2016_2018['speed'])

# %%
#taking the monthy averages of the speed of the current 
monthly_averages = dates_2016_2018.resample('1m').mean()

# %%
plt.figure(figsize = (10,5))
plt.plot(monthly_averages.index, monthly_averages['Eas'])
plt.xlabel('Time [year-month]')
plt.ylabel('Speed [cm/s]')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f01945fb5f16> in <module>
# ----> 1 plt.figure(figsize = (10,5))
#       2 plt.plot(monthly_averages.index, monthly_averages['Eas'])
#       3 plt.xlabel('Time [year-month]')
#       4 plt.ylabel('Speed [cm/s]')
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize = (10,5))
plt.plot(monthly_averages.index, monthly_averages['Current_mag'])
plt.xlabel('Time [year-month]')
plt.ylabel('Speed [cm/s]')
# Out:
# Text(0, 0.5, 'Speed [cm/s]')

# %%
date_time_number = (dates_2016_2018['dates']-np.datetime64('2000-01-01T00:00'))/np.timedelta64(1,'D')
#print(date_time_number)

#might need to convert dataframes to numpy arrays 
#this converts a time difference over a time difference to a number

# %%
#find longest uninterupted segment 
#U or v starting off 
#sampling frequency (put in times and then measurement values) 
#use datetime as number
#pick frequecies to go on x-axis (highest would be 1 hour- lowest would be defined as the record length = last minus first length of time )
#start with 100 arrays see what it gives me
#page 458

# %%
import scipy.signal as signal

# %%
data = dates_2016_2018['Easting (cm/sec)']

# %%
record_length = (date_time_number[-1]-date_time_number[0])
#top_time = (2*np.pi)/(1/24)
print(record_length)

top = 24*(np.pi*2)
freq = np.linspace(((1/record_length)*(np.pi*2)), top, 100)
# Out:
# 1020.1611111111106

# %%
top2 = np.log10(top)
first = np.log10((1/record_length)*(np.pi*2))

freq3 = np.logspace(first, top2, 1000)

# %%
pgram = signal.lombscargle(date_time_number, data, freq3)

freq4 = freq3/(2*np.pi)

# %%
plt.figure()
#plt.plot(freq, pgram)
plt.loglog(freq4,pgram)
plt.savefig('2016_spectral_analysis.png')

# %%
#pandas resample function '1h' gives exactly every hour  use .interpolate

# %%
hourly = dates_2016_2018.resample('1H').interpolate()

# %%
#print(hourly)
hourly_time_number = (hourly['dates']-np.datetime64('2000-01-01T00:00'))/np.timedelta64(1,'D')

# %%
plt.figure()
plt.plot(hourly.index,hourly['Easting (cm/sec)'])

# %%
plt.figure()
plt.plot(dates_2016_2018.index,dates_2016_2018['Easting (cm/sec)'])

# %%
#set interpolate to 2 hours

# %%
#separating out the data from the year 2011-2013
dates_2011_2013 = df.loc['2011-01-01':'2013-1-31']
dates_2011_2013['dates'] = dates_2011_2013.index

dates_2011_2013.head()
# Out:
# /Users/tomconnolly/programs/anaconda/envs/py37/lib/python3.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#                      Unnamed: 0 Date_time_Merge_hour  Current_mag  \
# Date_time_R
# 2011-11-20 13:11:00           1  2011-11-20 13:00:00     7.712734
# 2011-11-20 13:56:00           2  2011-11-20 14:00:00     1.711170
# 2011-11-20 14:55:00           3  2011-11-20 15:00:00     2.024802
# 2011-11-20 15:59:00           4  2011-11-20 16:00:00     3.567306
# 2011-11-20 18:22:00           6  2011-11-20 18:00:00     3.677635
#
#                      Easting (cm/sec)  Northing (cm/sec)  Minutes  Seconds  \
# Date_time_R
# 2011-11-20 13:11:00         -3.678000          -1.354000     10.8     32.0
# 2011-11-20 13:56:00          1.253333          -0.853333     16.0     13.0
# 2011-11-20 14:55:00          1.080000          -1.430000     25.0     30.0
# 2011-11-20 15:59:00         -1.413333          -3.036667     19.0     28.0
# 2011-11-20 18:22:00         -2.650000          -2.550000     22.0     32.0
#
#                                   dates
# Date_time_R
# 2011-11-20 13:11:00 2011-11-20 13:11:00
# 2011-11-20 13:56:00 2011-11-20 13:56:00
# 2011-11-20 14:55:00 2011-11-20 14:55:00
# 2011-11-20 15:59:00 2011-11-20 15:59:00
# 2011-11-20 18:22:00 2011-11-20 18:22:00

# %%
#calculating the speed of the current 
dates_2011_2013['speed'] = np.sqrt((dates_2011_2013['Easting (cm/sec)']**2) + (dates_2011_2013['Northing (cm/sec)']**2))
dates_2011_2013.head()
# Out:
# /Users/tomconnolly/programs/anaconda/envs/py37/lib/python3.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                      Unnamed: 0 Date_time_Merge_hour  Current_mag  \
# Date_time_R
# 2011-11-20 13:11:00           1  2011-11-20 13:00:00     7.712734
# 2011-11-20 13:56:00           2  2011-11-20 14:00:00     1.711170
# 2011-11-20 14:55:00           3  2011-11-20 15:00:00     2.024802
# 2011-11-20 15:59:00           4  2011-11-20 16:00:00     3.567306
# 2011-11-20 18:22:00           6  2011-11-20 18:00:00     3.677635
#
#                      Easting (cm/sec)  Northing (cm/sec)  Minutes  Seconds  \
# Date_time_R
# 2011-11-20 13:11:00         -3.678000          -1.354000     10.8     32.0
# 2011-11-20 13:56:00          1.253333          -0.853333     16.0     13.0
# 2011-11-20 14:55:00          1.080000          -1.430000     25.0     30.0
# 2011-11-20 15:59:00         -1.413333          -3.036667     19.0     28.0
# 2011-11-20 18:22:00         -2.650000          -2.550000     22.0     32.0
#
#                                   dates     speed
# Date_time_R
# 2011-11-20 13:11:00 2011-11-20 13:11:00  3.919311
# 2011-11-20 13:56:00 2011-11-20 13:56:00  1.516253
# 2011-11-20 14:55:00 2011-11-20 14:55:00  1.792010
# 2011-11-20 15:59:00 2011-11-20 15:59:00  3.349456
# 2011-11-20 18:22:00 2011-11-20 18:22:00  3.677635

# %%
monthly_averages_2011 = dates_2011_2013.resample('1m').mean()

# %%
plt.figure(figsize = (10,5))
plt.plot(monthly_averages_2011.index, monthly_averages_2011['speed'])
plt.xlabel('Time [year-month]')
plt.ylabel('Speed [cm/s]')
# Out:
# Text(0, 0.5, 'Speed [cm/s]')

# %%
date_time_number_2011 = (dates_2011_2013['dates']-np.datetime64('2000-01-01T00:00'))/np.timedelta64(1,'D')
data_2011 = dates_2011_2013['Easting (cm/sec)']
record_length_2011 = (date_time_number_2011[-1]-date_time_number_2011[0])
#top_time = (2*np.pi)/(1/24)
print(record_length)

top = 24*(np.pi*2)
freq_2011 = np.linspace(((1/record_length_2011)*(np.pi*2)), top, 100)
# Out:
# 1020.1611111111106

# %%
#freq_2011_2 = freq_2011/(2*np.pi)
top_2011 = np.log10(top)
first_2011 = np.log10((1/record_length_2011)*(np.pi*2))

freq_2011_2 = np.logspace(first_2011, top_2011, 100)

pgram_2011 = signal.lombscargle(date_time_number_2011, data_2011, freq_2011_2)

# %%
plt.figure()
plt.loglog(freq_2011_2, pgram_2011)
plt.savefig('2011_spectral_analysis.png')

# %%
#separating out the data from the year 2014-2015
dates_2014_2015 = df.loc['2014-01-01':'2015-6-30']
dates_2014_2015['dates'] = dates_2014_2015.index

dates_2014_2015.head()
# Out:
# /Users/tomconnolly/programs/anaconda/envs/py37/lib/python3.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#                      Unnamed: 0 Date_time_Merge_hour  Current_mag  \
# Date_time_R
# 2014-10-11 13:04:00       25344  2014-10-11 13:00:00     0.908994
# 2014-10-11 13:57:00       25345  2014-10-11 14:00:00     1.350541
# 2014-10-11 14:41:00       25346  2014-10-11 15:00:00     0.907747
# 2014-10-11 15:57:00       25347  2014-10-11 16:00:00     1.129383
# 2014-10-11 16:56:00       25348  2014-10-11 17:00:00     2.642760
#
#                      Easting (cm/sec)  Northing (cm/sec)    Minutes  Seconds  \
# Date_time_R
# 2014-10-11 13:04:00         -0.233333              0.860  44.333333     33.0
# 2014-10-11 13:57:00          0.330000             -0.160  26.500000     34.5
# 2014-10-11 14:41:00          0.200000             -0.325  40.500000     32.5
# 2014-10-11 15:57:00          0.980000             -0.280  27.500000     24.5
# 2014-10-11 16:56:00          2.380000             -1.065  25.500000     34.5
#
#                                   dates
# Date_time_R
# 2014-10-11 13:04:00 2014-10-11 13:04:00
# 2014-10-11 13:57:00 2014-10-11 13:57:00
# 2014-10-11 14:41:00 2014-10-11 14:41:00
# 2014-10-11 15:57:00 2014-10-11 15:57:00
# 2014-10-11 16:56:00 2014-10-11 16:56:00

# %%
#calculating the speed of the current 
dates_2014_2015['speed'] = np.sqrt((dates_2014_2015['Easting (cm/sec)']**2) + (dates_2014_2015['Northing (cm/sec)']**2))
dates_2014_2015.head()
# Out:
# /Users/tomconnolly/programs/anaconda/envs/py37/lib/python3.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                      Unnamed: 0 Date_time_Merge_hour  Current_mag  \
# Date_time_R
# 2014-10-11 13:04:00       25344  2014-10-11 13:00:00     0.908994
# 2014-10-11 13:57:00       25345  2014-10-11 14:00:00     1.350541
# 2014-10-11 14:41:00       25346  2014-10-11 15:00:00     0.907747
# 2014-10-11 15:57:00       25347  2014-10-11 16:00:00     1.129383
# 2014-10-11 16:56:00       25348  2014-10-11 17:00:00     2.642760
#
#                      Easting (cm/sec)  Northing (cm/sec)    Minutes  Seconds  \
# Date_time_R
# 2014-10-11 13:04:00         -0.233333              0.860  44.333333     33.0
# 2014-10-11 13:57:00          0.330000             -0.160  26.500000     34.5
# 2014-10-11 14:41:00          0.200000             -0.325  40.500000     32.5
# 2014-10-11 15:57:00          0.980000             -0.280  27.500000     24.5
# 2014-10-11 16:56:00          2.380000             -1.065  25.500000     34.5
#
#                                   dates     speed
# Date_time_R
# 2014-10-11 13:04:00 2014-10-11 13:04:00  0.891092
# 2014-10-11 13:57:00 2014-10-11 13:57:00  0.366742
# 2014-10-11 14:41:00 2014-10-11 14:41:00  0.381608
# 2014-10-11 15:57:00 2014-10-11 15:57:00  1.019215
# 2014-10-11 16:56:00 2014-10-11 16:56:00  2.607417

# %%
plt.figure()
plt.plot(dates_2014_2015.index, dates_2014_2015['speed'])

# %%
monthly_averages_2014 = dates_2014_2015.resample('1m').mean()

# %%
plt.figure(figsize = (10,5))
plt.plot(monthly_averages_2014.index, monthly_averages_2014['speed'])
plt.xlabel('Time [year-month]')
plt.ylabel('Speed [cm/s]')
# Out:
# Text(0, 0.5, 'Speed [cm/s]')

# %%
date_time_number_2014 = (dates_2014_2015['dates']-np.datetime64('2000-01-01T00:00'))/np.timedelta64(1,'D')
data_2014 = dates_2014_2015['Easting (cm/sec)']
record_length_2014 = (date_time_number_2014[-1]-date_time_number_2014[0])
#top_time = (2*np.pi)/(1/24)
print(record_length)

top = 24*(np.pi*2)
freq_2014 = np.linspace(((1/record_length_2014)*(np.pi*2)), top, 100)
# Out:
# 1020.1611111111106

# %%
#freq_2011_2 = freq_2011/(2*np.pi)
top_2014 = np.log10(top)
first_2014 = np.log10((1/record_length_2014)*(np.pi*2))

freq_2014_2 = np.logspace(first_2014, top_2014, 100)

pgram_2014 = signal.lombscargle(date_time_number_2014, data_2014, freq_2014_2)

# %%
plt.figure()
plt.loglog(freq_2014_2, pgram_2014)
plt.savefig('2014_spectral_analysis.png')
